# %%
import seaborn as sns
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('0hp_all_faults.csv')

# %% [markdown]
# # Segmenting the Vibration signal into small portions using a window

# %%
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical

win_len=1000
stride=200

X=[]
Y=[]


for k in df['fault'].unique():
    
    df_temp_2 = df[df['fault']==k]
    
    for i in np.arange(0,len(df_temp_2)-(win_len),stride):
        temp = df_temp_2.iloc[i:i+win_len,:-1].values
        temp = temp.reshape((1,-1))
        X.append(temp)
        Y.append(df_temp_2.iloc[i+win_len,-1])
    
X=np.array(X)
X=X.reshape((X.shape[0],win_len))



Y=np.array(Y)
encoder= LabelEncoder()
encoder.fit(Y)
encoded_Y = encoder.transform(Y)
OHE_Y = to_categorical(encoded_Y)

# %%
X.shape
# Out:
# (13848, 1000)

# %% [markdown]
# # Splitting the data into Train and Test

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,OHE_Y,test_size=0.3,shuffle=True)

# %% [markdown]
# # Visulaizing the data using t-sne before using Auto-Encoders

# %%
X_pre_aen = X

from sklearn.manifold import TSNE

X_t_sne = TSNE(n_components=2, learning_rate='auto',verbose=1, perplexity=40, n_iter=300).fit_transform(X_pre_aen)

tSNEdf = pd.DataFrame(data = X_t_sne, columns = ['t-SNE component 1', 't-SNE component 2'])

tSNEdf['Fault']=Y


# Plot the PC-1 and PC-2
fig, ax = plt.subplots(figsize=(7,7))
sns.scatterplot(x=tSNEdf['t-SNE component 1'],y=tSNEdf['t-SNE component 2'],hue='Fault',
    data=tSNEdf,
    legend="full",
    alpha=0.3)
plt.show()
# Out:
# C:\Users\mohan\.conda\envs\tensorflow\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 13848 samples in 0.027s...
# [t-SNE] Computed neighbors for 13848 samples in 10.490s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 13848
# [t-SNE] Computed conditional probabilities for sample 2000 / 13848
# [t-SNE] Computed conditional probabilities for sample 3000 / 13848
# [t-SNE] Computed conditional probabilities for sample 4000 / 13848
# [t-SNE] Computed conditional probabilities for sample 5000 / 13848
# [t-SNE] Computed conditional probabilities for sample 6000 / 13848
# [t-SNE] Computed conditional probabilities for sample 7000 / 13848
# [t-SNE] Computed conditional probabilities for sample 8000 / 13848
# [t-SNE] Computed conditional probabilities for sample 9000 / 13848
# [t-SNE] Computed conditional probabilities for sample 10000 / 13848
# [t-SNE] Computed conditional probabilities for sample 11000 / 13848
# [t-SNE] Computed conditional probabilities for sample 12000 / 13848
# [t-SNE] Computed conditional probabilities for sample 13000 / 13848
# [t-SNE] Computed conditional probabilities for sample 13848 / 13848
# [t-SNE] Mean sigma: 1.404057
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 93.106277
# [t-SNE] KL divergence after 300 iterations: 4.121871

# %%
tSNEdf
# Out:
#        t-SNE component 1  t-SNE component 2  Fault
# 0              -1.138317           1.697415  14_BA
# 1              -0.824761           2.379585  14_BA
# 2              -1.346384           2.193947  14_BA
# 3               1.353142           2.182032  14_BA
# 4               0.569780           1.668593  14_BA
# ...                  ...                ...    ...
# 13843          -1.030930           4.486088      N
# 13844          -1.905840           5.138860      N
# 13845          -0.741491           4.625963      N
# 13846          -1.697700           6.287065      N
# 13847          -1.095341           4.401536      N
#
# [13848 rows x 3 columns]

# %%
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.layers import Input,Dense, Dropout, Flatten


# from tensorflow.keras.models import load_model
# AE_model = load_model(r'Trained Model\AE_model_gear.h5')


no_classes=len(encoder.classes_)
# build a model
model = Sequential()
model.add(Dense(1024, input_shape=(X.shape[1],), activation='relu')) # input shape is (features,)
model.add(Dense(512, activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(no_classes, activation='softmax'))
model.summary()

# compile the model
model.compile(optimizer='adam', 
              loss='categorical_crossentropy', # this is different instead of binary_crossentropy (for regular classification)
              metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1024)              1025024
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_4 (Dense)              (None, 14)                1806
# =================================================================
# Total params: 1,715,854
# Trainable params: 1,715,854
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train,
                    y_train,
                    epochs=50, # you can set this to a big number!
                    batch_size=500,
                    shuffle=True,
                    validation_data=(X_test,y_test),
                    verbose=1)
# Out:
# Epoch 1/50
# 20/20 [==============================] - 1s 64ms/step - loss: 1.7562 - accuracy: 0.3776 - val_loss: 1.2106 - val_accuracy: 0.6152
# Epoch 2/50
# 20/20 [==============================] - 1s 50ms/step - loss: 0.9013 - accuracy: 0.7514 - val_loss: 0.6849 - val_accuracy: 0.8130
# Epoch 3/50
# 20/20 [==============================] - 1s 48ms/step - loss: 0.4026 - accuracy: 0.8965 - val_loss: 0.3808 - val_accuracy: 0.8739
# Epoch 4/50
# 20/20 [==============================] - 1s 54ms/step - loss: 0.2068 - accuracy: 0.9385 - val_loss: 0.3163 - val_accuracy: 0.8910
# Epoch 5/50
# 20/20 [==============================] - 1s 65ms/step - loss: 0.1502 - accuracy: 0.9554 - val_loss: 0.2520 - val_accuracy: 0.9211
# Epoch 6/50
# 20/20 [==============================] - 1s 74ms/step - loss: 0.1189 - accuracy: 0.9647 - val_loss: 0.2108 - val_accuracy: 0.9353
# Epoch 7/50
# 20/20 [==============================] - 2s 83ms/step - loss: 0.0894 - accuracy: 0.9749 - val_loss: 0.2172 - val_accuracy: 0.9353
# Epoch 8/50
# 20/20 [==============================] - 2s 89ms/step - loss: 0.0845 - accuracy: 0.9786 - val_loss: 0.2213 - val_accuracy: 0.9374
# Epoch 9/50
# 20/20 [==============================] - 2s 89ms/step - loss: 0.0587 - accuracy: 0.9847 - val_loss: 0.1523 - val_accuracy: 0.9540
# Epoch 10/50
# 20/20 [==============================] - 2s 90ms/step - loss: 0.0304 - accuracy: 0.9930 - val_loss: 0.1483 - val_accuracy: 0.9519
# Epoch 11/50
# 20/20 [==============================] - 2s 93ms/step - loss: 0.0248 - accuracy: 0.9941 - val_loss: 0.1509 - val_accuracy: 0.9581
# Epoch 12/50
# 20/20 [==============================] - 2s 92ms/step - loss: 0.0237 - accuracy: 0.9930 - val_loss: 0.1299 - val_accuracy: 0.9576
# Epoch 13/50
# 20/20 [==============================] - 2s 88ms/step - loss: 0.0082 - accuracy: 0.9990 - val_loss: 0.1259 - val_accuracy: 0.9605
# Epoch 14/50
# 20/20 [==============================] - 2s 95ms/step - loss: 0.0103 - accuracy: 0.9986 - val_loss: 0.1825 - val_accuracy: 0.9507
# Epoch 15/50
# 20/20 [==============================] - 2s 95ms/step - loss: 0.0128 - accuracy: 0.9975 - val_loss: 0.1487 - val_accuracy: 0.9574
# Epoch 16/50
# 20/20 [==============================] - 2s 86ms/step - loss: 0.0171 - accuracy: 0.9969 - val_loss: 0.1691 - val_accuracy: 0.9533
# Epoch 17/50
# 20/20 [==============================] - 1s 67ms/step - loss: 0.0169 - accuracy: 0.9961 - val_loss: 0.1277 - val_accuracy: 0.9646
# Epoch 18/50
# 20/20 [==============================] - 1s 71ms/step - loss: 0.0179 - accuracy: 0.9954 - val_loss: 0.1706 - val_accuracy: 0.9574
# Epoch 19/50
# 20/20 [==============================] - 1s 50ms/step - loss: 0.0355 - accuracy: 0.9916 - val_loss: 0.2414 - val_accuracy: 0.9410
# Epoch 20/50
# 20/20 [==============================] - 1s 37ms/step - loss: 0.4154 - accuracy: 0.9514 - val_loss: 0.2313 - val_accuracy: 0.9336
# Epoch 21/50
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0536 - accuracy: 0.9893 - val_loss: 0.1731 - val_accuracy: 0.9531
# Epoch 22/50
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0427 - accuracy: 0.9912 - val_loss: 0.1474 - val_accuracy: 0.9567
# Epoch 23/50
# 20/20 [==============================] - 1s 35ms/step - loss: 0.0394 - accuracy: 0.9907 - val_loss: 0.1588 - val_accuracy: 0.9548
# Epoch 24/50
# 20/20 [==============================] - 1s 34ms/step - loss: 0.0316 - accuracy: 0.9930 - val_loss: 0.1515 - val_accuracy: 0.9555
# Epoch 25/50
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0139 - accuracy: 0.9969 - val_loss: 0.1830 - val_accuracy: 0.9552
# Epoch 26/50
# 20/20 [==============================] - 1s 35ms/step - loss: 0.0094 - accuracy: 0.9982 - val_loss: 0.1347 - val_accuracy: 0.9646
# Epoch 27/50
# 20/20 [==============================] - 1s 35ms/step - loss: 0.0061 - accuracy: 0.9988 - val_loss: 0.1560 - val_accuracy: 0.9620
# Epoch 28/50
# 20/20 [==============================] - 1s 35ms/step - loss: 0.0080 - accuracy: 0.9989 - val_loss: 0.1227 - val_accuracy: 0.9697
# Epoch 29/50
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0096 - accuracy: 0.9977 - val_loss: 0.1347 - val_accuracy: 0.9697
# Epoch 30/50
# 20/20 [==============================] - ETA: 0s - loss: 0.0073 - accuracy: 0.99 - 1s 37ms/step - loss: 0.0073 - accuracy: 0.9987 - val_loss: 0.2107 - val_accuracy: 0.9564
# Epoch 31/50
# 20/20 [==============================] - 1s 34ms/step - loss: 0.0067 - accuracy: 0.9987 - val_loss: 0.1651 - val_accuracy: 0.9634
# Epoch 32/50
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0094 - accuracy: 0.9979 - val_loss: 0.1154 - val_accuracy: 0.9697
# Epoch 33/50
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0054 - accuracy: 0.9986 - val_loss: 0.1444 - val_accuracy: 0.9653
# Epoch 34/50
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0085 - accuracy: 0.9990 - val_loss: 0.1569 - val_accuracy: 0.9670
# Epoch 35/50
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0113 - accuracy: 0.9980 - val_loss: 0.1639 - val_accuracy: 0.9574
# Epoch 36/50
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0157 - accuracy: 0.9968 - val_loss: 0.2177 - val_accuracy: 0.9521
# Epoch 37/50
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0265 - accuracy: 0.9945 - val_loss: 0.2467 - val_accuracy: 0.9497
# Epoch 38/50
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0170 - accuracy: 0.9962 - val_loss: 0.1476 - val_accuracy: 0.9627
# Epoch 39/50
# 20/20 [==============================] - 1s 34ms/step - loss: 0.0049 - accuracy: 0.9988 - val_loss: 0.1392 - val_accuracy: 0.9651
# Epoch 40/50
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0076 - accuracy: 0.9987 - val_loss: 0.1658 - val_accuracy: 0.9627
# Epoch 41/50
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0165 - accuracy: 0.9963 - val_loss: 0.1618 - val_accuracy: 0.9605
# Epoch 42/50
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0064 - accuracy: 0.9986 - val_loss: 0.1369 - val_accuracy: 0.9644
# Epoch 43/50
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0108 - accuracy: 0.9974 - val_loss: 0.1580 - val_accuracy: 0.9600
# Epoch 44/50
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0157 - accuracy: 0.9958 - val_loss: 0.1948 - val_accuracy: 0.9519
# Epoch 45/50
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0073 - accuracy: 0.9982 - val_loss: 0.1263 - val_accuracy: 0.9682
# Epoch 46/50
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0030 - accuracy: 0.9993 - val_loss: 0.1319 - val_accuracy: 0.9677
# Epoch 47/50
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0011 - accuracy: 0.9999 - val_loss: 0.1235 - val_accuracy: 0.9728
# Epoch 48/50
# 20/20 [==============================] - 1s 32ms/step - loss: 8.4390e-04 - accuracy: 0.9999 - val_loss: 0.1293 - val_accuracy: 0.9704
# Epoch 49/50
# 20/20 [==============================] - 1s 32ms/step - loss: 8.8302e-04 - accuracy: 0.9998 - val_loss: 0.1096 - val_accuracy: 0.9721
# Epoch 50/50
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.1662 - val_accuracy: 0.9677

# %%
plt.plot(history.history['accuracy'],'go--')
plt.plot(history.history['val_accuracy'],'ro--')
plt.legend(['accuray','val_accuracy'])
plt.grid(color='k', linestyle='--', linewidth=0.5)
plt.show()

# %%
def inv_Transform_result(y_pred):    
    y_pred = y_pred.argmax(axis=1)
    y_pred = encoder.inverse_transform(y_pred)
    return y_pred



y_pred=model.predict(X_test)


Y_pred=inv_Transform_result(y_pred)
Y_test = inv_Transform_result(y_test)




from sklearn.metrics import confusion_matrix


plt.figure(figsize=(10,10))
cm = confusion_matrix(Y_test, Y_pred,normalize='true')
f = sns.heatmap(cm, annot=True,xticklabels=encoder.classes_,yticklabels=encoder.classes_)
plt.show()

# %%
dummy_ann = Model(inputs=model.input,outputs=model.layers[-2].output)
y_viz = dummy_ann.predict(X_train)

# %%
y_viz.shape
# Out:
# (9693, 128)

# %%
def T_SNE_plot(X_train,y_train,model,encoder):
    
    dummy_ann = Model(inputs=model.input,outputs=model.layers[-2].output)
    y_viz = dummy_ann.predict(X_train)
    
    from sklearn.manifold import TSNE

    X_t_sne = TSNE(n_components=2, learning_rate='auto',verbose=1, perplexity=40, n_iter=300).fit_transform(y_viz)

    tSNEdf = pd.DataFrame(data = X_t_sne, columns = ['T-SNE component 1', 'T-SNE component 2'])

    tSNEdf['Fault']=inv_Transform_result(y_train)


    # Plot the PC-1 and PC-2
    fig, ax = plt.subplots(figsize=(10,10))
    sns.scatterplot(x=tSNEdf['T-SNE component 1'],y=tSNEdf['T-SNE component 2'],hue='Fault',
        data=tSNEdf,
        legend="full",
        alpha=0.3)
    plt.show()

# %%
T_SNE_plot(X_train,y_train,model,encoder)
# Out:
# C:\Users\mohan\.conda\envs\tensorflow\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 9693 samples in 0.002s...
# [t-SNE] Computed neighbors for 9693 samples in 3.317s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 9693
# [t-SNE] Computed conditional probabilities for sample 2000 / 9693
# [t-SNE] Computed conditional probabilities for sample 3000 / 9693
# [t-SNE] Computed conditional probabilities for sample 4000 / 9693
# [t-SNE] Computed conditional probabilities for sample 5000 / 9693
# [t-SNE] Computed conditional probabilities for sample 6000 / 9693
# [t-SNE] Computed conditional probabilities for sample 7000 / 9693
# [t-SNE] Computed conditional probabilities for sample 8000 / 9693
# [t-SNE] Computed conditional probabilities for sample 9000 / 9693
# [t-SNE] Computed conditional probabilities for sample 9693 / 9693
# [t-SNE] Mean sigma: 2.539229
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 64.634796
# [t-SNE] KL divergence after 300 iterations: 2.128138

# %%
def Test_model_diff_loading(load,win_len,stride,model):
    
    df = pd.read_csv('{}hp_all_faults.csv'.format(load))

#     win_len=1000
#     stride=200

    X=[]
    Y=[]


    for k in df['fault'].unique():

        df_temp_2 = df[df['fault']==k]

        for i in np.arange(0,len(df_temp_2)-(win_len),stride):
            temp = df_temp_2.iloc[i:i+win_len,:-1].values
            temp = temp.reshape((1,-1))
            X.append(temp)
            Y.append(df_temp_2.iloc[i+win_len,-1])

    X=np.array(X)
    X=X.reshape((X.shape[0],win_len))



    Y=np.array(Y)
    encoder2= LabelEncoder()
    encoder2.fit(Y)
    encoded_Y = encoder2.transform(Y)
    OHE_Y = to_categorical(encoded_Y)


    def inv_Transform_result(y_pred,encoder):    
        y_pred = y_pred.argmax(axis=1)
        y_pred = encoder.inverse_transform(y_pred)
        return y_pred



    y_pred=model.predict(X)
    
    print('Accuracy on Load-{}hp data is---{}%'.format(load,(model.evaluate(X,OHE_Y)[1])*100))


    Y_pred=inv_Transform_result(y_pred,encoder2)
    Y_test = Y

    from sklearn.metrics import confusion_matrix


    plt.figure(figsize=(10,10))
    cm = confusion_matrix(Y_test, Y_pred,normalize='true')
    f = sns.heatmap(cm, annot=True,xticklabels=encoder.classes_,yticklabels=encoder.classes_)
    plt.show()
    print()
    
    T_SNE_plot(X[::10,:],OHE_Y[::10,:],model,encoder2)

# %%
Test_model_diff_loading(load=1,win_len=1000,stride=200,model=model)
# Out:
# 820/820 [==============================] - 2s 3ms/step - loss: 18.6165 - accuracy: 0.3537
# Accuracy on Load-1hp data is---35.37171185016632%
# C:\Users\mohan\.conda\envs\tensorflow\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 26230 samples in 0.000s...
# [t-SNE] Computed neighbors for 26230 samples in 16.802s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 26230
# [t-SNE] Computed conditional probabilities for sample 2000 / 26230
# [t-SNE] Computed conditional probabilities for sample 3000 / 26230
# [t-SNE] Computed conditional probabilities for sample 4000 / 26230
# [t-SNE] Computed conditional probabilities for sample 5000 / 26230
# [t-SNE] Computed conditional probabilities for sample 6000 / 26230
# [t-SNE] Computed conditional probabilities for sample 7000 / 26230
# [t-SNE] Computed conditional probabilities for sample 8000 / 26230
# [t-SNE] Computed conditional probabilities for sample 9000 / 26230
# [t-SNE] Computed conditional probabilities for sample 10000 / 26230
# [t-SNE] Computed conditional probabilities for sample 11000 / 26230
# [t-SNE] Computed conditional probabilities for sample 12000 / 26230
# [t-SNE] Computed conditional probabilities for sample 13000 / 26230
# [t-SNE] Computed conditional probabilities for sample 14000 / 26230
# [t-SNE] Computed conditional probabilities for sample 15000 / 26230
# [t-SNE] Computed conditional probabilities for sample 16000 / 26230
# [t-SNE] Computed conditional probabilities for sample 17000 / 26230
# [t-SNE] Computed conditional probabilities for sample 18000 / 26230
# [t-SNE] Computed conditional probabilities for sample 19000 / 26230
# [t-SNE] Computed conditional probabilities for sample 20000 / 26230
# [t-SNE] Computed conditional probabilities for sample 21000 / 26230
# [t-SNE] Computed conditional probabilities for sample 22000 / 26230
# [t-SNE] Computed conditional probabilities for sample 23000 / 26230
# [t-SNE] Computed conditional probabilities for sample 24000 / 26230
# [t-SNE] Computed conditional probabilities for sample 25000 / 26230
# [t-SNE] Computed conditional probabilities for sample 26000 / 26230
# [t-SNE] Computed conditional probabilities for sample 26230 / 26230
# [t-SNE] Mean sigma: 2.063272
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 81.971588
# [t-SNE] KL divergence after 300 iterations: 3.223864

# %%
Test_model_diff_loading(load=2,win_len=1000,stride=200,model=model)
# Out:
# 1063/1063 [==============================] - 3s 3ms/step - loss: 17.4933 - accuracy: 0.2983
# Accuracy on Load-2hp data is---29.83297109603882%
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 341 samples in 0.000s...
# [t-SNE] Computed neighbors for 341 samples in 0.016s...
# [t-SNE] Computed conditional probabilities for sample 341 / 341
# [t-SNE] Mean sigma: 10.498810
# C:\Users\mohan\.conda\envs\tensorflow\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 49.653587
# [t-SNE] KL divergence after 300 iterations: 0.313116

# %%
Test_model_diff_loading(load=3,win_len=1000,stride=200,model=model)
# Out:
# 1063/1063 [==============================] - 3s 3ms/step - loss: 17.2750 - accuracy: 0.2728
# Accuracy on Load-3hp data is---27.278608083724976%
# C:\Users\mohan\.conda\envs\tensorflow\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 3402 samples in 0.000s...
# [t-SNE] Computed neighbors for 3402 samples in 0.301s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 3402
# [t-SNE] Computed conditional probabilities for sample 2000 / 3402
# [t-SNE] Computed conditional probabilities for sample 3000 / 3402
# [t-SNE] Computed conditional probabilities for sample 3402 / 3402
# [t-SNE] Mean sigma: 3.990030
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 66.239899
# [t-SNE] KL divergence after 300 iterations: 1.713284
